# %% [markdown]
# # NER with BERT in Spark NLP

# %% [markdown]
# <h5>Import libraries and download datasets</h5>

# %%
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline

import sparknlp
from sparknlp.annotator import *
from sparknlp.common import *
from sparknlp.base import *

# %%
data_folder = r"../../Dataset/"

spark = sparknlp.start(gpu=True)
print("Spark NLP version: ", sparknlp.version())
print("Apache Spark version: ", spark.version)
# Out:
# Spark NLP version:  2.6.2
# Apache Spark version:  2.4.7

# %% [markdown]
# <h5>Building NER pipeline</h5>

# %%
# Convert the CoNLL file to Spark data frame with additional fields
path = data_folder+"conll2003/eng.train";
with open(path) as f:
    c=f.read()

print (c[:500])
# Out:
# -DOCSTART- -X- -X- O
#
# EU NNP B-NP B-ORG
# rejects VBZ B-VP O
# German JJ B-NP B-MISC
# call NN I-NP O
# to TO B-VP O
# boycott VB I-VP O
# British JJ B-NP B-MISC
# lamb NN I-NP O
# . . O O
#
# Peter NNP B-NP B-PER
# Blackburn NNP I-NP I-PER
#
# BRUSSELS NNP B-NP B-LOC
# 1996-08-22 CD I-NP O
#
# The DT B-NP O
# European NNP I-NP B-ORG
# Commission NNP I-NP I-ORG
# said VBD B-VP O
# on IN B-PP O
# Thursday NNP B-NP O
# it PRP B-NP O
# disagreed VBD B-VP O
# with IN B-PP O
# German JJ B-NP B-MISC
# advice NN I-NP O
# to TO B-PP O
# consumers NNS B-NP

# %%
from sparknlp.training import CoNLL
training_data = CoNLL().readDataset(spark, path)
training_data.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                text|            document|            sentence|               token|                 pos|               label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |EU rejects German...|[[document, 0, 47...|[[document, 0, 47...|[[token, 0, 1, EU...|[[pos, 0, 1, NNP,...|[[named_entity, 0...|
# |     Peter Blackburn|[[document, 0, 14...|[[document, 0, 14...|[[token, 0, 4, Pe...|[[pos, 0, 4, NNP,...|[[named_entity, 0...|
# | BRUSSELS 1996-08-22|[[document, 0, 18...|[[document, 0, 18...|[[token, 0, 7, BR...|[[pos, 0, 7, NNP,...|[[named_entity, 0...|
# |The European Comm...|[[document, 0, 18...|[[document, 0, 18...|[[token, 0, 2, Th...|[[pos, 0, 2, DT, ...|[[named_entity, 0...|
# |Germany 's repres...|[[document, 0, 21...|[[document, 0, 21...|[[token, 0, 6, Ge...|[[pos, 0, 6, NNP,...|[[named_entity, 0...|
# |" We do n't suppo...|[[document, 0, 16...|[[document, 0, 16...|[[token, 0, 0, ",...|[[pos, 0, 0, ", [...|[[named_entity, 0...|
# |He said further s...|[[document, 0, 13...|[[document, 0, 13...|[[token, 0, 1, He...|[[pos, 0, 1, PRP,...|[[named_entity, 0...|
# |He said a proposa...|[[document, 0, 22...|[[document, 0, 22...|[[token, 0, 1, He...|[[pos, 0, 1, PRP,...|[[named_entity, 0...|
# |Fischler proposed...|[[document, 0, 18...|[[document, 0, 18...|[[token, 0, 7, Fi...|[[pos, 0, 7, JJR,...|[[named_entity, 0...|
# |But Fischler agre...|[[document, 0, 21...|[[document, 0, 21...|[[token, 0, 2, Bu...|[[pos, 0, 2, CC, ...|[[named_entity, 0...|
# |Spanish Farm Mini...|[[document, 0, 16...|[[document, 0, 16...|[[token, 0, 6, Sp...|[[pos, 0, 6, NNP,...|[[named_entity, 0...|
# |                   .|[[document, 0, 0,...|[[document, 0, 0,...|[[token, 0, 0, .,...|[[pos, 0, 0, ., [...|[[named_entity, 0...|
# |Only France and B...|[[document, 0, 52...|[[document, 0, 52...|[[token, 0, 3, On...|[[pos, 0, 3, RB, ...|[[named_entity, 0...|
# |The EU 's scienti...|[[document, 0, 17...|[[document, 0, 17...|[[token, 0, 2, Th...|[[pos, 0, 2, DT, ...|[[named_entity, 0...|
# |Sheep have long b...|[[document, 0, 17...|[[document, 0, 17...|[[token, 0, 4, Sh...|[[pos, 0, 4, NNP,...|[[named_entity, 0...|
# |British farmers d...|[[document, 0, 21...|[[document, 0, 21...|[[token, 0, 6, Br...|[[pos, 0, 6, JJ, ...|[[named_entity, 0...|
# |" What we have to...|[[document, 0, 18...|[[document, 0, 18...|[[token, 0, 0, ",...|[[pos, 0, 0, ", [...|[[named_entity, 0...|
# |Bonn has led effo...|[[document, 0, 21...|[[document, 0, 21...|[[token, 0, 3, Bo...|[[pos, 0, 3, NNP,...|[[named_entity, 0...|
# |Germany imported ...|[[document, 0, 84...|[[document, 0, 84...|[[token, 0, 6, Ge...|[[pos, 0, 6, NNP,...|[[named_entity, 0...|
# |It brought in 4,2...|[[document, 0, 82...|[[document, 0, 82...|[[token, 0, 1, It...|[[pos, 0, 1, PRP,...|[[named_entity, 0...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
training_data.count()
# Out:
# 14041

# %% [markdown]
# <h5>Loading Bert</h5>

# %% [markdown]
# In Spark NLP, we have four pre-trained variants of BERT: <b>bert_base_uncased</b> , <b>bert_base_cased</b> , <b>bert_large_uncased</b> , <b>bert_large_cased</b> . Which one to use depends on your use case, train set, and the complexity of the task you are trying to model.
#
# In the code snippet above, we basically load the bert_base_cased version from Spark NLP public resources and point the sentence and token columns in setInputCols(). In short, BertEmbeddings() annotator will take sentence and token columns and populate Bert embeddings in bert column. In general, each word is translated to a 768-dimensional vector. The parameter setPoolingLayer() can be set to 0 as the first layer and fastest, -1 as the last layer and -2 as the second-to-last-hidden layer.
#
# As explained by the authors of official BERT paper, different BERT layers capture different information. The last layer is too closed to the target functions (i.e. masked language model and next sentence prediction) during pre-training, therefore it may be biased to those targets. If you want to use the last hidden layer anyway, please feel free to set pooling_layer=-1. Intuitively, pooling_layer=-1 is close to the training output, so it may be biased to the training targets. If you don't fine-tune the model, then this could lead to a bad representation. That said, it is a matter of trade-off between model accuracy and computational resources you have.

# %%
bert_annotator = BertEmbeddings.pretrained('bert_base_cased', 'en') \
 .setInputCols(["sentence",'token'])\
 .setOutputCol("bert")\
 .setCaseSensitive(False)
# Out:
# bert_base_cased download started this may take some time.
# Approximate size to download 389.1 MB
# [OK!]

# %%
from sparknlp.training import CoNLL

test_data = CoNLL().readDataset(spark, data_folder+"conll2003/eng.testa")
test_data = bert_annotator.transform(test_data)
test_data.write.parquet("test_withEmbeds.parquet")
test_data.show(3)
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                text|            document|            sentence|               token|                 pos|               label|                bert|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |CRICKET - LEICEST...|[[document, 0, 64...|[[document, 0, 64...|[[token, 0, 6, CR...|[[pos, 0, 6, NNP,...|[[named_entity, 0...|[[word_embeddings...|
# |   LONDON 1996-08-30|[[document, 0, 16...|[[document, 0, 16...|[[token, 0, 5, LO...|[[pos, 0, 5, NNP,...|[[named_entity, 0...|[[word_embeddings...|
# |West Indian all-r...|[[document, 0, 18...|[[document, 0, 18...|[[token, 0, 3, We...|[[pos, 0, 3, NNP,...|[[named_entity, 0...|[[word_embeddings...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 3 rows

# %%
test_data.select("bert.result","bert.embeddings",'label.result').show()
# Out:
# +--------------------+--------------------+--------------------+
# |              result|          embeddings|              result|
# +--------------------+--------------------+--------------------+
# |[cricket, -, leic...|[[0.36637592, -0....|[O, O, B-ORG, O, ...|
# |[london, 1996-08-30]|[[0.78848666, -0....|          [B-LOC, O]|
# |[west, indian, al...|[[0.3852343, -0.5...|[B-MISC, I-MISC, ...|
# |[their, stay, on,...|[[0.4464562, -0.4...|[O, O, O, O, O, O...|
# |[after, bowling, ...|[[0.50563043, -0....|[O, O, B-ORG, O, ...|
# |[trailing, by, 21...|[[0.4501431, -0.8...|[O, O, O, O, B-OR...|
# |[essex, ,, howeve...|[[0.72113115, -0....|[B-ORG, O, O, O, ...|
# |[hussain, ,, cons...|[[0.4423417, -0.8...|[B-PER, O, O, O, ...|
# |[by, the, close, ...|[[0.21335557, -0....|[O, O, O, B-ORG, ...|
# |[at, the, oval, ,...|[[0.53978103, -0....|[O, O, B-LOC, O, ...|
# |[he, was, well, b...|[[0.46333486, -0....|[O, O, O, O, O, B...|
# |[derbyshire, kept...|[[-0.35205558, 0....|[B-ORG, O, O, O, ...|
# |[australian, tom,...|[[0.6310952, -0.6...|[B-MISC, B-PER, I...|
# |[after, the, frus...|[[0.59393436, -0....|[O, O, O, O, O, O...|
# |[they, were, held...|[[0.85634965, -0....|[O, O, O, O, O, O...|
# |[by, stumps, kent...|[[0.011020819, -0...|[O, O, B-ORG, O, ...|
# |[cricket, -, engl...|[[0.43483084, -0....|[O, O, B-MISC, I-...|
# |[london, 1996-08-30]|[[0.78848666, -0....|          [B-LOC, O]|
# |[result, and, clo...|[[-0.31441832, -0...|[O, O, O, O, O, O...|
# |[leicester, :, le...|[[0.7253388, -0.4...|[B-LOC, O, B-ORG,...|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
import numpy as np

emb_vector = np.array(test_data.select("bert.embeddings").take(1))
emb_vector
# Out:
# array([[[[ 0.36637592, -0.86787492,  0.18460657, ...,  0.19050074,
#            0.31882697,  0.21404736],
#          [ 0.0042053 , -0.7304967 ,  0.10252799, ...,  0.72762662,
#            0.23618948,  0.54797202],
#          [ 0.53181094, -0.21557562,  0.11225671, ...,  0.6807006 ,
#           -0.73567241,  0.51040608],
#          ...,
#          [ 0.57870978,  0.06638508, -0.49203444, ...,  0.2483449 ,
#            0.50983089,  0.2516709 ],
#          [ 0.15336806, -0.28964311, -0.2610296 , ...,  0.42096072,
#            0.40467095,  0.25303409],
#          [ 0.05699301,  0.32524562,  0.06525278, ...,  0.18811801,
#            0.14695087,  0.07696211]]]])

# %%
nerTagger = NerDLApproach()\
  .setInputCols(["sentence", "token", "bert"])\
  .setLabelColumn("label")\
  .setOutputCol("ner")\
  .setMaxEpochs(1)\
  .setLr(0.001)\
  .setPo(0.005)\
  .setBatchSize(8)\
  .setRandomSeed(0)\
  .setVerbose(1)\
  .setValidationSplit(0.2)\
  .setEvaluationLogExtended(True) \
  .setEnableOutputLogs(True)\
  .setIncludeConfidence(True)\
  .setTestDataset("test_withEmbeds.parquet")


pipeline = Pipeline(
    stages = [
    bert_annotator,
    nerTagger
  ])

# %% [markdown]
# You can also set learning rate ( setLr ), learning rate decay coefficient ( setPo ), setBatchSize and setDropout rate. Please see the official repo for the entire list.

# %%
# %%time

ner_model = pipeline.fit(training_data.limit(1000))
# Out:
# CPU times: user 46.2 ms, sys: 22.5 ms, total: 68.7 ms
# Wall time: 3min 14s

# %%
ner_model
# Out:
# PipelineModel_ae4f53a349f4

# %%
predictions = ner_model.transform(test_data)
predictions.show(3)
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                text|            document|            sentence|               token|                 pos|               label|                bert|                 ner|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |CRICKET - LEICEST...|[[document, 0, 64...|[[document, 0, 64...|[[token, 0, 6, CR...|[[pos, 0, 6, NNP,...|[[named_entity, 0...|[[word_embeddings...|[[named_entity, 0...|
# |   LONDON 1996-08-30|[[document, 0, 16...|[[document, 0, 16...|[[token, 0, 5, LO...|[[pos, 0, 5, NNP,...|[[named_entity, 0...|[[word_embeddings...|[[named_entity, 0...|
# |West Indian all-r...|[[document, 0, 18...|[[document, 0, 18...|[[token, 0, 3, We...|[[pos, 0, 3, NNP,...|[[named_entity, 0...|[[word_embeddings...|[[named_entity, 0...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 3 rows

# %%
predictions.select('token.result','label.result','ner.result').show(truncate=40)
# Out:
# +----------------------------------------+----------------------------------------+----------------------------------------+
# |                                  result|                                  result|                                  result|
# +----------------------------------------+----------------------------------------+----------------------------------------+
# |[CRICKET, -, LEICESTERSHIRE, TAKE, OV...|   [O, O, B-ORG, O, O, O, O, O, O, O, O]|   [O, O, B-ORG, O, O, O, O, O, O, O, O]|
# |                    [LONDON, 1996-08-30]|                              [B-LOC, O]|                              [B-LOC, O]|
# |[West, Indian, all-rounder, Phil, Sim...|[B-MISC, I-MISC, O, B-PER, I-PER, O, ...|[B-PER, B-PER, B-PER, I-PER, I-PER, O...|
# |[Their, stay, on, top, ,, though, ,, ...|[O, O, O, O, O, O, O, O, O, O, O, O, ...|[O, O, O, O, O, O, O, O, O, O, O, O, ...|
# |[After, bowling, Somerset, out, for, ...|[O, O, B-ORG, O, O, O, O, O, O, O, O,...|[O, O, B-PER, O, O, O, O, O, O, O, O,...|
# |[Trailing, by, 213, ,, Somerset, got,...|[O, O, O, O, B-ORG, O, O, O, O, O, O,...|[O, O, O, O, B-ORG, O, O, O, O, O, O,...|
# |[Essex, ,, however, ,, look, certain,...|[B-ORG, O, O, O, O, O, O, O, O, O, O,...|[B-ORG, O, O, O, O, O, O, O, O, O, O,...|
# |[Hussain, ,, considered, surplus, to,...|[B-PER, O, O, O, O, B-LOC, O, O, O, O...|[B-PER, O, O, O, O, B-ORG, O, O, O, O...|
# |[By, the, close, Yorkshire, had, turn...|[O, O, O, B-ORG, O, O, O, O, O, O, O,...|[O, O, O, O, O, O, O, O, O, O, O, O, ...|
# |[At, the, Oval, ,, Surrey, captain, C...|[O, O, B-LOC, O, B-ORG, O, B-PER, I-P...|[O, O, O, O, B-PER, O, B-PER, I-PER, ...|
# |[He, was, well, backed, by, England, ...|[O, O, O, O, O, B-LOC, O, B-PER, I-PE...|[O, O, O, O, O, O, O, O, O, O, O, O, ...|
# |[Derbyshire, kept, up, the, hunt, for...|[B-ORG, O, O, O, O, O, O, O, O, O, O,...|[B-ORG, O, O, O, O, O, O, O, O, O, O,...|
# |[Australian, Tom, Moody, took, six, f...|[B-MISC, B-PER, I-PER, O, O, O, O, O,...|[B-PER, B-PER, I-PER, O, O, O, O, O, ...|
# |[After, the, frustration, of, seeing,...|[O, O, O, O, O, O, O, O, O, O, O, O, ...|[O, O, O, O, O, O, O, O, O, O, O, O, ...|
# |[They, were, held, up, by, a, gritty,...|[O, O, O, O, O, O, O, O, O, B-PER, I-...|[O, O, O, O, O, O, O, O, O, B-PER, B-...|
# |[By, stumps, Kent, had, reached, 108,...|         [O, O, B-ORG, O, O, O, O, O, O]|             [O, O, O, O, O, O, O, O, O]|
# |[CRICKET, -, ENGLISH, COUNTY, CHAMPIO...|    [O, O, B-MISC, I-MISC, I-MISC, O, O]|                   [O, O, O, O, O, O, O]|
# |                    [LONDON, 1996-08-30]|                              [B-LOC, O]|                              [B-LOC, O]|
# |[Result, and, close, of, play, scores...|[O, O, O, O, O, O, O, B-MISC, O, O, O...|[O, O, O, O, O, O, O, B-MISC, I-MISC,...|
# |[Leicester, :, Leicestershire, beat, ...|[B-LOC, O, B-ORG, O, B-ORG, O, O, O, ...|[B-PER, O, B-LOC, O, B-LOC, O, O, O, ...|
# +----------------------------------------+----------------------------------------+----------------------------------------+
# only showing top 20 rows

# %%
predictions.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- document: array (nullable = false)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)
#  |-- sentence: array (nullable = false)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)
#  |-- token: array (nullable = false)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)
#  |-- pos: array (nullable = false)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)
#  |-- label: array (nullable = false)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)
#  |-- bert: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)
#  |-- ner: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)

# %%
import pyspark.sql.functions as F

predictions.select(F.explode(F.arrays_zip('token.result','label.result','ner.result')).alias("cols")) \
.select(F.expr("cols['0']").alias("token"),
        F.expr("cols['1']").alias("ground_truth"),
        F.expr("cols['2']").alias("prediction")).show(truncate=False)
# Out:
# +--------------+------------+----------+
# |token         |ground_truth|prediction|
# +--------------+------------+----------+
# |CRICKET       |O           |O         |
# |-             |O           |O         |
# |LEICESTERSHIRE|B-ORG       |B-ORG     |
# |TAKE          |O           |O         |
# |OVER          |O           |O         |
# |AT            |O           |O         |
# |TOP           |O           |O         |
# |AFTER         |O           |O         |
# |INNINGS       |O           |O         |
# |VICTORY       |O           |O         |
# |.             |O           |O         |
# |LONDON        |B-LOC       |B-LOC     |
# |1996-08-30    |O           |O         |
# |West          |B-MISC      |B-PER     |
# |Indian        |I-MISC      |B-PER     |
# |all-rounder   |O           |B-PER     |
# |Phil          |B-PER       |I-PER     |
# |Simmons       |I-PER       |I-PER     |
# |took          |O           |O         |
# |four          |O           |O         |
# +--------------+------------+----------+
# only showing top 20 rows

# %% [markdown]
# <h5> Loading from Local</h5>

# %%
ner_model.stages[1].write().save('NER_bert_20200221')

# %%
# loading the one trained 10 epochs on GPU with entire train set
loaded_ner_model = NerDLModel.load("NER_bert_20200221")\
 .setInputCols(["sentence", "token", "bert"])\
 .setOutputCol("ner")

# %%
predictions_loaded = loaded_ner_model.transform(test_data)

predictions_loaded.select(F.explode(F.arrays_zip('token.result','label.result','ner.result')).alias("cols")) \
.select(F.expr("cols['0']").alias("token"),
        F.expr("cols['1']").alias("ground_truth"),
        F.expr("cols['2']").alias("prediction")).show(30, truncate=False)
# Out:
# +--------------+------------+----------+
# |token         |ground_truth|prediction|
# +--------------+------------+----------+
# |CRICKET       |O           |O         |
# |-             |O           |O         |
# |LEICESTERSHIRE|B-ORG       |B-ORG     |
# |TAKE          |O           |O         |
# |OVER          |O           |O         |
# |AT            |O           |O         |
# |TOP           |O           |O         |
# |AFTER         |O           |O         |
# |INNINGS       |O           |O         |
# |VICTORY       |O           |O         |
# |.             |O           |O         |
# |LONDON        |B-LOC       |B-LOC     |
# |1996-08-30    |O           |O         |
# |West          |B-MISC      |B-PER     |
# |Indian        |I-MISC      |B-PER     |
# |all-rounder   |O           |B-PER     |
# |Phil          |B-PER       |I-PER     |
# |Simmons       |I-PER       |I-PER     |
# |took          |O           |O         |
# |four          |O           |O         |
# |for           |O           |O         |
# |38            |O           |O         |
# |on            |O           |O         |
# |Friday        |O           |O         |
# |as            |O           |O         |
# |Leicestershire|B-ORG       |B-ORG     |
# |beat          |O           |O         |
# |Somerset      |B-ORG       |B-ORG     |
# |by            |O           |O         |
# |an            |O           |O         |
# +--------------+------------+----------+
# only showing top 30 rows

# %%
import pandas as pd

df = predictions_loaded.select('token.result','label.result','ner.result').toPandas()

df
# Out:
#                                                  result  \
# 0     [CRICKET, -, LEICESTERSHIRE, TAKE, OVER, AT, T...
# 1                                  [LONDON, 1996-08-30]
# 2     [West, Indian, all-rounder, Phil, Simmons, too...
# 3     [Their, stay, on, top, ,, though, ,, may, be, ...
# 4     [After, bowling, Somerset, out, for, 83, on, t...
# 5     [Trailing, by, 213, ,, Somerset, got, a, solid...
# 6     [Essex, ,, however, ,, look, certain, to, rega...
# 7     [Hussain, ,, considered, surplus, to, England,...
# 8     [By, the, close, Yorkshire, had, turned, that,...
# 9     [At, the, Oval, ,, Surrey, captain, Chris, Lew...
# 10    [He, was, well, backed, by, England, hopeful, ...
# 11    [Derbyshire, kept, up, the, hunt, for, their, ...
# 12    [Australian, Tom, Moody, took, six, for, 82, b...
# 13    [After, the, frustration, of, seeing, the, ope...
# 14    [They, were, held, up, by, a, gritty, 84, from...
# 15    [By, stumps, Kent, had, reached, 108, for, thr...
# 16    [CRICKET, -, ENGLISH, COUNTY, CHAMPIONSHIP, SC...
# 17                                 [LONDON, 1996-08-30]
# 18    [Result, and, close, of, play, scores, in, Eng...
# 19    [Leicester, :, Leicestershire, beat, Somerset,...
# 20    [Somerset, 83, and, 174, (, P., Simmons, 4-38,...
# 21      [Leicestershire, 22, points, ,, Somerset, 4, .]
# 22    [Chester-le-Street, :, Glamorgan, 259, and, 20...
# 23    [Tunbridge, Wells, :, Nottinghamshire, 214, (,...
# 24    [London, (, The, Oval, ), :, Warwickshire, 195...
# 25    [Hove, :, Sussex, 363, (, W., Athey, 111, ,, V...
# 26    [Portsmouth, :, Middlesex, 199, and, 426, (, J...
# 27    [Chesterfield, :, Worcestershire, 238, and, 13...
# 28    [Bristol, :, Gloucestershire, 183, and, 185-6,...
# 29             [CRICKET, -, 1997, ASHES, INTINERARY, .]
# ...                                                 ...
# 3220  [Jordan, defends, his, decision, to, make, the...
# 3221  [", The, film, spares, neither, the, Irish, no...
# 3222  [How, often, has, independence, been, achieved...
# 3223                               [Very, rarely, ., "]
# 3224  [Jordan, ,, whose, 1992, film, ", The, Crying,...
# 3225  [", He, developed, techniques, of, guerilla, w...
# 3226  [", Collins, would, never, be, a, proponent, o...
# 3227  [He, was, a, soldier, and, a, statesman, and, ...
# 3228  [Leeson, ,, the, Northern, Ireland-born, actor...
# 3229  [Aidan, Quinn, portrays, Harry, Boland, ,, Col...
# 3230  [Much, of, the, film, was, shot, on, location,...
# 3231  [A, set, ,, however, ,, was, used, for, the, f...
# 3232  [Noting, that, information, about, Collins, wa...
# 3233  [", I, have, made, choices, about, certain, ev...
# 3234  [I, wanted, to, make, this, a, story, as, accu...
# 3235                [It, is, a, very, true, film, ., "]
# 3236  [One, of, the, assumptions, is, his, interpret...
# 3237  [", I, have, never, lost, more, sleep, over, t...
# 3238  [", In, the, life, of, one, person, you, can, ...
# 3239  [Dhaka, stocks, seen, steady, in, absence, of,...
# 3240                                [DHAKA, 1996-08-31]
# 3241  [Shares, on, the, Dhaka, Stock, Exchange, (, D...
# 3242  [", The, market, is, expected, to, remain, ste...
# 3243  [There, will, be, both, buying, and, selling, ...
# 3244  [Broker, Khurshid, Alam, said, :, ", The, mark...
# 3245  [But, the, prices, may, move, in, a, close, ra...
# 3246  [Brokers, said, blue, chips, like, IDLC, ,, Ba...
# 3247  [They, said, there, was, still, demand, for, b...
# 3248  [The, DSE, all, share, price, index, closed, 2...
# 3249                [--, Dhaka, Newsroom, 880-2-506363]
#
#                                                  result  \
# 0                 [O, O, B-ORG, O, O, O, O, O, O, O, O]
# 1                                            [B-LOC, O]
# 2     [B-MISC, I-MISC, O, B-PER, I-PER, O, O, O, O, ...
# 3     [O, O, O, O, O, O, O, O, O, O, O, O, O, B-ORG,...
# 4     [O, O, B-ORG, O, O, O, O, O, O, O, O, B-LOC, I...
# 5     [O, O, O, O, B-ORG, O, O, O, O, O, O, O, O, O,...
# 6     [B-ORG, O, O, O, O, O, O, O, O, O, O, O, B-PER...
# 7     [B-PER, O, O, O, O, B-LOC, O, O, O, O, O, O, O...
# 8     [O, O, O, B-ORG, O, O, O, O, O, O, O, O, O, B-...
# 9     [O, O, B-LOC, O, B-ORG, O, B-PER, I-PER, O, O,...
# 10    [O, O, O, O, O, B-LOC, O, B-PER, I-PER, O, O, ...
# 11    [B-ORG, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 12    [B-MISC, B-PER, I-PER, O, O, O, O, O, B-PER, I...
# 13    [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 14    [O, O, O, O, O, O, O, O, O, B-PER, I-PER, O, B...
# 15                      [O, O, B-ORG, O, O, O, O, O, O]
# 16                 [O, O, B-MISC, I-MISC, I-MISC, O, O]
# 17                                           [B-LOC, O]
# 18      [O, O, O, O, O, O, O, B-MISC, O, O, O, O, O, O]
# 19     [B-LOC, O, B-ORG, O, B-ORG, O, O, O, O, O, O, O]
# 20    [B-ORG, O, O, O, O, B-PER, I-PER, O, O, O, B-O...
# 21                        [B-ORG, O, O, O, B-ORG, O, O]
# 22    [B-LOC, O, B-ORG, O, O, O, O, B-PER, I-PER, O,...
# 23    [B-LOC, I-LOC, O, B-ORG, O, O, B-PER, I-PER, O...
# 24    [B-LOC, O, B-LOC, I-LOC, O, O, B-ORG, O, O, B-...
# 25    [B-LOC, O, B-ORG, O, O, B-PER, I-PER, O, O, B-...
# 26    [B-LOC, O, B-ORG, O, O, O, O, B-PER, I-PER, O,...
# 27    [B-LOC, O, B-ORG, O, O, O, O, B-ORG, O, O, B-P...
# 28    [B-LOC, O, B-ORG, O, O, O, O, B-PER, I-PER, O,...
# 29                              [O, O, O, B-MISC, O, O]
# ...                                                 ...
# 3220  [B-PER, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 3221  [O, O, O, O, O, O, B-MISC, O, O, B-MISC, O, O,...
# 3222                        [O, O, O, O, O, O, O, O, O]
# 3223                                       [O, O, O, O]
# 3224  [B-PER, O, O, O, O, O, B-MISC, I-MISC, I-MISC,...
# 3225  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3226     [O, B-PER, O, O, O, O, O, O, O, O, O, O, O, O]
# 3227  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3228  [B-PER, O, O, B-MISC, I-MISC, O, O, O, O, O, O...
# 3229  [B-PER, I-PER, O, B-PER, I-PER, O, B-PER, O, O...
# 3230  [O, O, O, O, O, O, O, O, O, B-LOC, O, B-PER, O...
# 3231               [O, O, O, O, O, O, O, O, O, O, O, O]
# 3232  [O, O, O, O, B-PER, O, O, O, O, O, O, O, O, O,...
# 3233  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3234  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3235                           [O, O, O, O, O, O, O, O]
# 3236  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3237  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3238  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3239                 [B-LOC, O, O, O, O, O, O, O, O, O]
# 3240                                         [B-LOC, O]
# 3241  [O, O, O, B-ORG, I-ORG, I-ORG, O, B-ORG, O, O,...
# 3242                        [O, O, O, O, O, O, O, O, O]
# 3243  [O, O, O, O, O, O, O, O, O, O, O, O, B-PER, I-...
# 3244    [O, B-PER, I-PER, O, O, O, O, O, O, O, O, O, O]
# 3245   [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O]
# 3246  [O, O, O, O, O, B-ORG, O, B-ORG, I-ORG, O, B-O...
# 3247  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3248  [O, B-ORG, O, O, O, O, O, O, O, O, O, O, O, O,...
# 3249                               [O, B-ORG, I-ORG, O]
#
#                                                  result
# 0                 [O, O, B-ORG, O, O, O, O, O, O, O, O]
# 1                                            [B-LOC, O]
# 2     [B-PER, B-PER, B-PER, I-PER, I-PER, O, O, O, O...
# 3     [O, O, O, O, O, O, O, O, O, O, O, O, O, B-ORG,...
# 4     [O, O, B-PER, O, O, O, O, O, O, O, O, O, O, O,...
# 5     [O, O, O, O, B-ORG, O, O, O, O, O, O, O, O, O,...
# 6     [B-ORG, O, O, O, O, O, O, O, O, O, O, O, B-PER...
# 7     [B-PER, O, O, O, O, B-ORG, O, O, O, O, O, O, O...
# 8     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 9     [O, O, O, O, B-PER, O, B-PER, I-PER, O, O, O, ...
# 10    [O, O, O, O, O, O, O, O, O, O, O, O, O, B-ORG,...
# 11    [B-ORG, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 12    [B-PER, B-PER, I-PER, O, O, O, O, O, B-PER, I-...
# 13    [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 14    [O, O, O, O, O, O, O, O, O, B-PER, B-PER, O, O...
# 15                          [O, O, O, O, O, O, O, O, O]
# 16                                [O, O, O, O, O, O, O]
# 17                                           [B-LOC, O]
# 18    [O, O, O, O, O, O, O, B-MISC, I-MISC, I-MISC, ...
# 19     [B-PER, O, B-LOC, O, B-LOC, O, O, O, O, O, O, O]
# 20    [B-ORG, O, O, O, O, O, B-ORG, O, O, O, B-ORG, ...
# 21                        [B-ORG, O, O, O, B-ORG, O, O]
# 22    [B-PER, O, B-PER, O, O, O, O, B-PER, B-PER, O,...
# 23    [B-PER, O, O, B-PER, O, O, B-PER, B-PER, O, O,...
# 24    [B-PER, O, O, O, O, O, B-PER, O, O, B-PER, O, ...
# 25    [B-PER, O, B-PER, O, O, B-PER, B-PER, O, O, B-...
# 26    [B-PER, O, I-PER, O, O, O, O, B-PER, B-PER, O,...
# 27    [B-PER, O, I-PER, O, O, O, O, B-PER, O, O, B-P...
# 28    [B-PER, O, B-PER, O, O, O, O, B-PER, I-PER, O,...
# 29                                   [O, O, O, O, O, O]
# ...                                                 ...
# 3220  [B-PER, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 3221  [O, O, O, O, O, O, B-MISC, O, O, B-LOC, O, O, ...
# 3222                        [O, O, O, O, O, O, O, O, O]
# 3223                                       [O, O, O, O]
# 3224  [B-PER, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 3225  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3226     [O, B-ORG, O, O, O, O, O, O, O, O, O, O, O, O]
# 3227  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3228  [B-PER, O, O, O, B-PER, O, O, O, O, O, O, B-PE...
# 3229  [B-PER, I-PER, O, B-PER, I-PER, O, I-PER, O, O...
# 3230  [O, O, O, O, O, O, O, O, O, B-ORG, O, B-LOC, O...
# 3231               [O, O, O, O, O, O, O, O, O, O, O, O]
# 3232  [O, O, O, O, B-ORG, O, O, O, O, O, O, O, O, O,...
# 3233  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3234  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3235                           [O, O, O, O, O, O, O, O]
# 3236  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3237  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3238  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3239                 [B-PER, O, O, O, O, O, O, O, O, O]
# 3240                                         [B-LOC, O]
# 3241  [O, O, O, B-PER, O, O, O, B-PER, O, O, O, O, O...
# 3242                        [O, O, O, O, O, O, O, O, O]
# 3243  [O, O, O, O, O, O, O, O, O, O, O, O, B-PER, I-...
# 3244    [O, B-PER, I-PER, O, O, O, O, O, O, O, O, O, O]
# 3245   [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O]
# 3246  [O, O, O, O, O, B-PER, O, B-PER, O, O, B-PER, ...
# 3247  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3248  [O, B-PER, O, O, O, O, O, O, O, O, O, O, O, O,...
# 3249                                   [O, B-PER, O, O]
#
# [3250 rows x 3 columns]

# %% [markdown]
# <h5>Bert with poolingLayer -2</h5>

# %%
bert_annotator.setPoolingLayer(-2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-7f07661f4a53> in <module>()
# ----> 1 bert_annotator.setPoolingLayer(-2)
#
# AttributeError: 'BertEmbeddings' object has no attribute 'setPoolingLayer'

# %%
pipeline = Pipeline(
    stages = [
    bert_annotator,
    nerTagger
  ])

# %%
ner_model_v2 = pipeline.fit(training_data.limit(1000))
